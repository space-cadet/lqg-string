# %% [markdown]
# # Geometry with Manim

# %% [markdown]
# Note: Using conda `langchain` environment

# %%
from manim import *

# %%
# %%manim -qm CurvedSurfaceExample
#
# class CurvedSurfaceExample(ThreeDScene):
#     def construct(self):
#         # Set up the scene
#         self.set_camera_orientation(phi=75 * DEGREES, theta=-30 * DEGREES)
#
#         # Create a parametric surface
#         def param_surface(u, v):
#             x = u
#             y = v
#             z = np.sin(u) * np.cos(v)
#             return np.array([x, y, z])
#
#         surface = Surface(
#             param_surface,
#             u_range=[-2, 2],
#             v_range=[-2, 2],
#             resolution=(30, 30),
#             checkerboard_colors=[BLUE_D, BLUE_E],
#             stroke_width=0.5,
#         )
#
#         # Add the surface to the scene
#         self.add(surface)
#
#         # Animate the camera
#         # self.begin_ambient_camera_rotation(rate=0.1)
#         # self.wait(10)
# Out:
# Manim Community v0.18.1
#
# [10/15/24 22:33:53] INFO                                ]8;id=402107;file:///Users/deepak/miniconda3/envs/langchain/lib/python3.9/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=368243;file:///Users/deepak/miniconda3/envs/langchain/lib/python3.9/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/Volumes/Data/owncloud/ro
#                              ot/research/articles/lqg-s
#                              tring/manim/media/images/m
#                              anim/CurvedSurfaceExample_
#                              ManimCE_v0.18.1.png'
#
#                     INFO     Rendered CurvedSurfaceExample          ]8;id=520468;file:///Users/deepak/miniconda3/envs/langchain/lib/python3.9/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=125951;file:///Users/deepak/miniconda3/envs/langchain/lib/python3.9/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations

# %%
from manim import Sur
